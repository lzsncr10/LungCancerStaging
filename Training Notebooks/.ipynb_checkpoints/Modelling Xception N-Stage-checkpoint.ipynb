# %% [markdown]
# ## Modelling Draft <br>
# Framework: Tensorflow Keras <br>
# Base models to test: <br>
# <li>Xception ✓</li>
# <li>MobileNet </li>
# <li>NasNet Mobile </li>

# %% [markdown]
# #### Import Packages

# %%
# from PIL import Image
# from tensorflow.keras import backend as K
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow
import random
import os
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Dropout, BatchNormalization, Flatten, Input
from tensorflow.keras.optimizers import *
from tensorflow.keras.metrics import *
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications.xception import preprocess_input
from sklearn.model_selection import train_test_split
from sklearn.metrics._plot.confusion_matrix import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils import class_weight
from time import perf_counter

import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199
print ('All modules are loaded')
# Out:
# All modules are loaded

# %%
#Labels
# t_stg= ['is','1','1a','1b','1c','2','2a','2b','3','4']
n_stg = ['0','1','2','3']
# m_stg = ['0','1','1a','1b','1c','2','3'] 

#Load the image batches, labels == t,m,n
n_raw_df = pd.read_csv(r'D:\Lung-PET-CT-Dx\manifest\raw_ct_delimited.csv',usecols=['filenames','n'])
raw_dir = r'C:\Users\lzsnc\Desktop\Raw CT resized'
n_raw_df.head()

# %%
n_raw_df.head()
# Out:
#                                                               filenames  n
# 0  Lung_Dx-A0001_04-04-2007-NA-Chest-07990_2.000000-5mm-40805_1-13.tiff  3
# 1  Lung_Dx-A0001_04-04-2007-NA-Chest-07990_2.000000-5mm-40805_1-14.tiff  3
# 2  Lung_Dx-A0001_04-04-2007-NA-Chest-07990_2.000000-5mm-40805_1-15.tiff  3
# 3  Lung_Dx-A0001_04-04-2007-NA-Chest-07990_2.000000-5mm-40805_1-16.tiff  3
# 4  Lung_Dx-A0001_04-04-2007-NA-Chest-07990_2.000000-5mm-40805_1-17.tiff  3

# %% [markdown]
# #### Split Dataset: <br>
# 80% Train, 20% Test

# %%
n_train_df, n_test_df = train_test_split(n_raw_df, test_size=0.2, random_state=42) #fix this, need x_train, x_test, y_train, y_test
n_train_df.tail()
# Out:
#                                                                                                              filenames  \
# 29802             Lung_Dx-G0060_01-21-2011-NA-PET01PTheadlung Adult-07418_10.000000-Thorax  1.0  B70f-17914_1-168.tiff
# 5390   Lung_Dx-A0170_12-02-2010-NA-PET03CBMWholebodyFirstHead Adult-02190_10.000000-Thorax  1.0  B70f-48719_1-150.tiff
# 860                                  Lung_Dx-A0030_10-08-2008-NA-LUNGCTA-12839_2.000000-5mm Stnd SS50-99357_3-034.tiff
# 15795     Lung_Dx-A0242_06-30-2010-NA-PET03WholebodyFirstHead Adult-08887_10.000000-Thorax  1.0  B70f-74050_1-077.tiff
# 23654                          Lung_Dx-G0017_10-24-2009-NA-LUNGC-80644_2.000000-A phase 5mm Stnd SS50-33209_2-033.tiff
#
#        n
# 29802  1
# 5390   2
# 860    3
# 15795  0
# 23654  0

# %%
#convert 'n' stage value to string
n_train_df['n'] = n_train_df['n'].apply(str)
n_test_df['n'] = n_test_df['n'].apply(str)
n_test_df.head()
# Out:
#                                                                                                                                filenames  \
# 13351  Lung_Dx-A0225_02-24-2010-NA-PET03WholebodyFirstHead Adult-94548_17.000000-Range-CT WB  1.0  B30f-Tra-ALPHA Range-84398_1-097.tiff
# 6885   Lung_Dx-A0179_02-18-2011-NA-PETNEW02CBMWholebodyOnly Adult-71135_6.000000-Range-CT WB  1.0  B30f-Tra-ALPHA Range-45198_1-138.tiff
# 1588                                                      Lung_Dx-A0065_10-26-2008-NA-lungc-32319_3.000000-5mm Lung SS50-68818_1-34.tiff
# 1109                     Lung_Dx-A0041_05-20-2009-NA-ThoraxAThoraxRoutine Adult-95129_3.000000-ThoraxRoutine  10.0  B40f-76978_1-08.tiff
# 8980                         Lung_Dx-A0193_09-16-2009-NA-PET03WholebodyFirstHead Adult-73161_15.000000-CT WB  1.0  B30f-21761_1-135.tiff
#
#        n
# 13351  0
# 6885   0
# 1588   1
# 1109   1
# 8980   1

# %% [markdown]
# #### Train/Test for 'T' Stage

# %%
train_batch = 32
train_datagen = ImageDataGenerator(rescale=1 / 255.0,
                                   featurewise_center=True,
                                   featurewise_std_normalization=True,)

n_train_ds = train_datagen.flow_from_dataframe(
    dataframe=n_train_df,
    directory=raw_dir,
    x_col='filenames',
    y_col='n',
    class_mode='categorical',
    shuffle=True,
    seed=32
)
# Out:
# Found 24250 validated image filenames belonging to 4 classes.

# %%
np.unique(n_train_ds.classes)
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# #### Test Image Generator

# %%
test_batch = 32
test_datagen = ImageDataGenerator(rescale=1 / 255.0)
n_test_ds = test_datagen.flow_from_dataframe(
    dataframe=n_test_df,
    directory=raw_dir,
    x_col='filenames',
    y_col='n',
    class_mode='categorical',
    shuffle=False, 
    seed=32 
)
# Out:
# Found 6063 validated image filenames belonging to 4 classes.

# %%
#try adding weights to resolve undersamples
n_class_dict = n_train_ds.class_indices
print(n_class_dict)
n_num_classes = len(n_class_dict)
n_num_classes
# Out:
# {'0': 0, '1': 1, '2': 2, '3': 3}
# 4

# %%
n_class_dict
# Out:
# {'0': 0, '1': 1, '2': 2, '3': 3}

# %% [markdown]
# Add Weights to Solve Data Imbalance

# %%
n_class_weights = class_weight.compute_class_weight(
           class_weight='balanced',
           classes=np.unique(n_train_ds.classes),
           y=n_train_ds.classes)
n_class_weights = dict(zip(np.unique(n_train_ds.classes), n_class_weights))
n_class_weights
# Out:
# {0: 0.47807743868780067,
#  1: 0.887628111273792,
#  2: 6.020357497517378,
#  3: 1.6244640943193998}

# %% [markdown]
# Model 3: Xception

# %%
base_model = Xception(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

base_model.trainable = False
base_model.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 111, 111, 32)         864       ['input_1[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 111, 111, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 111, 111, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 109, 109, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 109, 109, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 109, 109, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 109, 109, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 109, 109, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 109, 109, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 109, 109, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 109, 109, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d (Conv2D)             (None, 55, 55, 128)          8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 55, 55, 128)          0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (Batch  (None, 55, 55, 128)          512       ['conv2d[0][0]']
#  Normalization)
#
#  add (Add)                   (None, 55, 55, 128)          0         ['block2_pool[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activ  (None, 55, 55, 128)          0         ['add[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 55, 55, 256)          33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 55, 55, 256)          1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 55, 55, 256)          0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 55, 55, 256)          67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 55, 55, 256)          1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 256)          32768     ['add[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (Bat  (None, 28, 28, 256)          1024      ['conv2d_1[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 28, 28, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 28, 28, 256)          0         ['add_1[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 28, 28, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 28, 28, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 28, 28, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 28, 28, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 28, 28, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 728)          186368    ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (Bat  (None, 14, 14, 728)          2912      ['conv2d_2[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 14, 14, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_2[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_3 (Add)                 (None, 14, 14, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_2[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_3[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_4 (Add)                 (None, 14, 14, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_3[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_4[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_5 (Add)                 (None, 14, 14, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_4[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_5[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_6 (Add)                 (None, 14, 14, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_5[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_6[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_7 (Add)                 (None, 14, 14, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_6[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_7[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_8 (Add)                 (None, 14, 14, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_7[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_8[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_9 (Add)                 (None, 14, 14, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_8[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_9[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_10 (Add)                (None, 14, 14, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_9[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_10[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 14, 14, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 14, 14, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 1024)           745472    ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 7, 7, 1024)           0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_3 (Bat  (None, 7, 7, 1024)           4096      ['conv2d_3[0][0]']
#  chNormalization)
#
#  add_11 (Add)                (None, 7, 7, 1024)           0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_3[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 7, 7, 1536)           1582080   ['add_11[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 7, 7, 1536)           6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 7, 7, 1536)           0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 7, 7, 2048)           3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 7, 7, 2048)           8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 7, 7, 2048)           0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
# ==================================================================================================
# Total params: 20861480 (79.58 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 20861480 (79.58 MB)
# __________________________________________________________________________________________________

# %%
#Add random seed
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tensorflow.random.set_seed(seed_value) #use in dropout

# %%
#Create the model
model = Sequential()
model.add(base_model)
# model.add(Dropout(0.3))
model.add(tensorflow.keras.layers.GlobalAveragePooling2D())
model.add(BatchNormalization(axis = -1, momentum = 0.99, epsilon = 0.001))
model.add(tensorflow.keras.layers.Reshape((-1,1)))
model.add(tensorflow.keras.layers.AveragePooling1D())
model.add(Flatten())
model.add(Dropout(0.3,seed=seed_value))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3,seed=seed_value))
model.add(Dense(n_num_classes,activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  batch_normalization_4 (Bat  (None, 2048)              8192
#  chNormalization)
#
#  reshape (Reshape)           (None, 2048, 1)           0
#
#  average_pooling1d (Average  (None, 1024, 1)           0
#  Pooling1D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 21005132 (80.13 MB)
# Trainable params: 139556 (545.14 KB)
# Non-trainable params: 20865576 (79.60 MB)
# _________________________________________________________________

# %%
learning_rate = 0.0001
optimizer = tensorflow.keras.optimizers.Adam(learning_rate=learning_rate)
loss = tensorflow.keras.losses.CategoricalCrossentropy(from_logits=True)
model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

# %% [markdown]
# Actual Training

# %%
os.chdir(r'D:\Lung-PET-CT-Dx\manifest\Models')
checkpoint_callback = tensorflow.keras.callbacks.ModelCheckpoint("multiclass_n_stage_xception_v2.h5",
                     save_best_only=True, # only keep the best model weights on file (delete the rest)
                     save_weights_only=False,   # save only the model weights
                     verbose=1, # don't print out whether or not model is being saved
                     monitor='val_loss')
                    #  mode='max') # save the model weights which score the best validation accuracy
early_stop = tensorflow.keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                              mode='auto',
                                              patience=5)

# %%
start = perf_counter()
history = model.fit(n_train_ds,
                    epochs=20,
                    steps_per_epoch=len(n_train_ds),
                    validation_data=n_test_ds,
                    validation_steps=len(n_test_ds),
                    callbacks=[checkpoint_callback, early_stop],
                    verbose=1,
                    class_weight=n_class_weights)
end = perf_counter()
print(end - start)
# Out:
# Epoch 1/20
# 758/758 [==============================] - ETA: 0s - loss: 1.4040 - accuracy: 0.3879
# Epoch 1: val_loss improved from inf to 1.12939, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2191s 3s/step - loss: 1.4040 - accuracy: 0.3879 - val_loss: 1.1294 - val_accuracy: 0.5154
# Epoch 2/20
# 758/758 [==============================] - ETA: 0s - loss: 1.1207 - accuracy: 0.4542
# Epoch 2: val_loss improved from 1.12939 to 0.99840, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2178s 3s/step - loss: 1.1207 - accuracy: 0.4542 - val_loss: 0.9984 - val_accuracy: 0.5799
# Epoch 3/20
# 758/758 [==============================] - ETA: 0s - loss: 0.9786 - accuracy: 0.5146
# Epoch 3: val_loss improved from 0.99840 to 0.87827, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2216s 3s/step - loss: 0.9786 - accuracy: 0.5146 - val_loss: 0.8783 - val_accuracy: 0.6434
# Epoch 4/20
# 758/758 [==============================] - ETA: 0s - loss: 0.8851 - accuracy: 0.5536
# Epoch 4: val_loss improved from 0.87827 to 0.78782, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2185s 3s/step - loss: 0.8851 - accuracy: 0.5536 - val_loss: 0.7878 - val_accuracy: 0.6914
# Epoch 5/20
# 758/758 [==============================] - ETA: 0s - loss: 0.8050 - accuracy: 0.5899
# Epoch 5: val_loss improved from 0.78782 to 0.72473, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2212s 3s/step - loss: 0.8050 - accuracy: 0.5899 - val_loss: 0.7247 - val_accuracy: 0.7152
# Epoch 6/20
# 758/758 [==============================] - ETA: 0s - loss: 0.7580 - accuracy: 0.6141
# Epoch 6: val_loss improved from 0.72473 to 0.68555, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2112s 3s/step - loss: 0.7580 - accuracy: 0.6141 - val_loss: 0.6856 - val_accuracy: 0.7323
# Epoch 7/20
# 758/758 [==============================] - ETA: 0s - loss: 0.7125 - accuracy: 0.6313
# Epoch 7: val_loss improved from 0.68555 to 0.63896, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2103s 3s/step - loss: 0.7125 - accuracy: 0.6313 - val_loss: 0.6390 - val_accuracy: 0.7509
# Epoch 8/20
# 758/758 [==============================] - ETA: 0s - loss: 0.6591 - accuracy: 0.6491
# Epoch 8: val_loss improved from 0.63896 to 0.59770, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2114s 3s/step - loss: 0.6591 - accuracy: 0.6491 - val_loss: 0.5977 - val_accuracy: 0.7633
# Epoch 9/20
# 758/758 [==============================] - ETA: 0s - loss: 0.6368 - accuracy: 0.6666
# Epoch 9: val_loss improved from 0.59770 to 0.57107, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2136s 3s/step - loss: 0.6368 - accuracy: 0.6666 - val_loss: 0.5711 - val_accuracy: 0.7851
# Epoch 10/20
# 758/758 [==============================] - ETA: 0s - loss: 0.6093 - accuracy: 0.6766
# Epoch 10: val_loss improved from 0.57107 to 0.53388, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2117s 3s/step - loss: 0.6093 - accuracy: 0.6766 - val_loss: 0.5339 - val_accuracy: 0.7978
# Epoch 11/20
# 758/758 [==============================] - ETA: 0s - loss: 0.5904 - accuracy: 0.6878
# Epoch 11: val_loss improved from 0.53388 to 0.50874, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2114s 3s/step - loss: 0.5904 - accuracy: 0.6878 - val_loss: 0.5087 - val_accuracy: 0.8047
# Epoch 12/20
# 758/758 [==============================] - ETA: 0s - loss: 0.5634 - accuracy: 0.6993
# Epoch 12: val_loss improved from 0.50874 to 0.47962, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2120s 3s/step - loss: 0.5634 - accuracy: 0.6993 - val_loss: 0.4796 - val_accuracy: 0.8148
# Epoch 13/20
# 758/758 [==============================] - ETA: 0s - loss: 0.5513 - accuracy: 0.7066
# Epoch 13: val_loss improved from 0.47962 to 0.45984, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2117s 3s/step - loss: 0.5513 - accuracy: 0.7066 - val_loss: 0.4598 - val_accuracy: 0.8265
# Epoch 14/20
# 758/758 [==============================] - ETA: 0s - loss: 0.5320 - accuracy: 0.7171
# Epoch 14: val_loss improved from 0.45984 to 0.45414, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2122s 3s/step - loss: 0.5320 - accuracy: 0.7171 - val_loss: 0.4541 - val_accuracy: 0.8270
# Epoch 15/20
# 758/758 [==============================] - ETA: 0s - loss: 0.5109 - accuracy: 0.7253
# Epoch 15: val_loss improved from 0.45414 to 0.42507, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2125s 3s/step - loss: 0.5109 - accuracy: 0.7253 - val_loss: 0.4251 - val_accuracy: 0.8367
# Epoch 16/20
# 758/758 [==============================] - ETA: 0s - loss: 0.4857 - accuracy: 0.7420
# Epoch 16: val_loss improved from 0.42507 to 0.39938, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2143s 3s/step - loss: 0.4857 - accuracy: 0.7420 - val_loss: 0.3994 - val_accuracy: 0.8483
# Epoch 17/20
# 758/758 [==============================] - ETA: 0s - loss: 0.4783 - accuracy: 0.7402
# Epoch 17: val_loss improved from 0.39938 to 0.38958, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2146s 3s/step - loss: 0.4783 - accuracy: 0.7402 - val_loss: 0.3896 - val_accuracy: 0.8545
# Epoch 18/20
# 758/758 [==============================] - ETA: 0s - loss: 0.4604 - accuracy: 0.7530
# Epoch 18: val_loss improved from 0.38958 to 0.37855, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2156s 3s/step - loss: 0.4604 - accuracy: 0.7530 - val_loss: 0.3786 - val_accuracy: 0.8603
# Epoch 19/20
# 758/758 [==============================] - ETA: 0s - loss: 0.4511 - accuracy: 0.7566
# Epoch 19: val_loss improved from 0.37855 to 0.36375, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2149s 3s/step - loss: 0.4511 - accuracy: 0.7566 - val_loss: 0.3638 - val_accuracy: 0.8634
# Epoch 20/20
# 758/758 [==============================] - ETA: 0s - loss: 0.4311 - accuracy: 0.7657
# Epoch 20: val_loss improved from 0.36375 to 0.34722, saving model to multiclass_n_stage_xception_v2.h5
# 758/758 [==============================] - 2152s 3s/step - loss: 0.4311 - accuracy: 0.7657 - val_loss: 0.3472 - val_accuracy: 0.8690
# 42908.3531094

# %% [markdown]
# Load model - skip training <br>
# Approximate training time: 42908.3531094 seconds

# %%
#Evaluate performance
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
plot_loss_curves(history)

# %%
n_Y_pred = model.predict(n_test_ds) #predictions
n_Y_ground = n_test_df.n.to_list()
n_y_pred = np.argmax(n_Y_pred,axis=1)
print('Confusion Matrix')
cm = confusion_matrix(n_test_ds.classes, n_y_pred)
# cm = confusion_matrix(t_Y_ground, t_Y_pred,normalize='true')
cmd = ConfusionMatrixDisplay(cm, display_labels=n_stg)
cmd.plot()

print('Classification Report for N-Stage')

print(classification_report(n_test_ds.classes, n_y_pred, target_names=n_stg))
# Out:
# 190/190 [==============================] - 431s 2s/step
# Confusion Matrix
# Classification Report for N-Stage
#               precision    recall  f1-score   support
#
#            0       0.97      0.82      0.89      3158
#            1       0.81      0.88      0.84      1708
#            2       0.84      0.99      0.91       272
#            3       0.76      0.97      0.85       925
#
#     accuracy                           0.87      6063
#    macro avg       0.84      0.92      0.87      6063
# weighted avg       0.88      0.87      0.87      6063

# %%
from tensorflow.keras.preprocessing import image
test_img = r'C:\Users\lzsnc\Desktop\Raw CT Images\Lung_Dx-A0030_10-08-2008-NA-LUNGCTA-12839_2.000000-5mm Stnd SS50-99357_1-037.tiff'
test = image.load_img(test_img, target_size=(224,224))
test_img_array = image.img_to_array(test)
img_batch = np.expand_dims(test_img_array, axis=0)
img_preprocessed = preprocess_input(img_batch)
prediction = model.predict(img_preprocessed)
print(prediction[0])
# Out:
# 1/1 [==============================] - 1s 730ms/step
# [1.7209709e-01 2.3550196e-01 3.5142963e-05 5.9236580e-01]
